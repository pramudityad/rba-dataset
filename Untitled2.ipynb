# %%
import pandas as pd
df = pd.read_csv('rba-dataset-renamed-desktop.csv')
df = df.head(10000)
df.head()
# Out:
#    index          login_timestamp              user_id  round_trip  \
# 0     10  2020-02-03 12:44:19.260  5932501938287412564         NaN
# 1     16  2020-02-03 12:44:31.854 -4663943525943860871         NaN
# 2     18  2020-02-03 12:44:33.093 -4324475583306591935         NaN
# 3     19  2020-02-03 12:44:33.239  1211299018980019605         NaN
# 4     28  2020-02-03 12:44:44.504 -4324475583306591935         NaN
#
#        ip_address country       region         city     asn  \
# 0    84.48.61.135      NO            -            -   15659
# 1  81.166.109.168      NO     Rogaland    Haugesund   29695
# 2  46.183.175.255      NO            -            -  197475
# 3     10.0.77.207      NO  Oslo County         Oslo   29695
# 4   79.161.39.219      NO        Viken  Solbergelva   29695
#
#                                    user_agent_string                 browser  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6...        Chrome 86.0.4202
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6...        Chrome 86.0.4202
# 2  Mozilla/5.0 (X11; CrOS aarch64 11316.123.0) Ap...        Chrome 72.0.3626
# 3  Mozilla/5.0  (X11; CrOS armv7l 5978.98.0) Appl...  Chrome 69.0.3497.17.19
# 4  Mozilla/5.0  (Macintosh; Intel Mac OS X 10_14_...        Chrome 90.0.4411
#
#                os_detail device_type  is_login_success  is_attack_ip  \
# 0       Mac OS X 10.14.6     desktop              True         False
# 1       Mac OS X 10.14.6     desktop              True         False
# 2  Chrome OS 11316.123.0     desktop             False         False
# 3    Chrome OS 5978.98.0     desktop              True         False
# 4       Mac OS X 10.14.6     desktop             False         False
#
#    is_account_takeover
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False

# %% [markdown]
# ### View summary of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                10000 non-null  int64
#  1   login_timestamp      10000 non-null  object
#  2   user_id              10000 non-null  int64
#  3   round_trip           0 non-null      float64
#  4   ip_address           10000 non-null  object
#  5   country              10000 non-null  object
#  6   region               9996 non-null   object
#  7   city                 9997 non-null   object
#  8   asn                  10000 non-null  int64
#  9   user_agent_string    10000 non-null  object
#  10  browser              10000 non-null  object
#  11  os_detail            10000 non-null  object
#  12  device_type          10000 non-null  object
#  13  is_login_success     10000 non-null  bool
#  14  is_attack_ip         10000 non-null  bool
#  15  is_account_takeover  10000 non-null  bool
# dtypes: bool(3), float64(1), int64(3), object(9)
# memory usage: 1.0+ MB

# %%
# calculate the percentage of True and False values in bolean char'
value_counts_1 = df['is_login_success'].value_counts(normalize=True)
is_login_success_true = value_counts_1[True] * 100
is_login_success_false = value_counts_1[False] * 100
print("is_login_success")
print(f"Percentage of True values: {is_login_success_true:.2f}%")
print(f"Percentage of False values: {is_login_success_false:.2f}%")

value_counts_2 = df['is_attack_ip'].value_counts(normalize=True)
is_attack_ip_true  = value_counts_2[True] * 100
is_attack_ip_false = value_counts_2[False] * 100
print("is_attack_ip")
print(f"Percentage of True values: {is_attack_ip_true:.2f}%")
print(f"Percentage of False values: {is_attack_ip_false:.2f}%")

# value_counts_3 = df['is_account_takeover'].value_counts(normalize=True)
# is_account_takeover_true  = value_counts_3[True] * 100
# is_account_takeover_false = value_counts_3[False] * 100
# print("is_account_takeover")
# print(f"Percentage of True values: {is_account_takeover_true:.2f}%")
# print(f"Percentage of False values: {is_account_takeover_false:.2f}%")
# Out:
# is_login_success
# Percentage of True values: 63.72%
# Percentage of False values: 36.28%
# is_attack_ip
# Percentage of True values: 3.70%
# Percentage of False values: 96.30%

# %% [markdown]
# #### findings
# - dataset contains 9 character variables, 3 character numerical and 3 character boolean
# - the target is `is_login_success` based on calculation percentage above

# %%
df.describe()
# Out:
#               index       user_id  round_trip            asn
# count  10000.000000  1.000000e+04         0.0   10000.000000
# mean   48199.627200 -1.082034e+18         NaN   93487.358400
# std    28538.554109  5.009296e+18         NaN  149766.528227
# min       10.000000 -9.222772e+18         NaN     224.000000
# 25%    23229.750000 -4.324476e+18         NaN   29695.000000
# 50%    48266.500000 -3.215765e+18         NaN   29695.000000
# 75%    72351.250000  3.163367e+18         NaN   45916.000000
# max    99116.000000  9.217264e+18         NaN  507361.000000

# %%
# check for missing values
df.isnull().sum()
# Out:
# index                      0
# login_timestamp            0
# user_id                    0
# round_trip             10000
# ip_address                 0
# country                    0
# region                     4
# city                       3
# asn                        0
# user_agent_string          0
# browser                    0
# os_detail                  0
# device_type                0
# is_login_success           0
# is_attack_ip               0
# is_account_takeover        0
# dtype: int64

# %% [markdown]
# ### drop un-used column

# %%
# drop columns index, is_attack_ip, is_account_takeover
df.drop(['round_trip','index', 'is_attack_ip', 'is_account_takeover'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# login_timestamp      0
# user_id              0
# ip_address           0
# country              0
# region               4
# city                 3
# asn                  0
# user_agent_string    0
# browser              0
# os_detail            0
# device_type          0
# is_login_success     0
# dtype: int64

# %% [markdown]
# ### List of features

# %%
def initial_eda(df):
    if isinstance(df, pd.DataFrame):
        total_na = df.isna().sum().sum()
        print("Dimensions : %d rows, %d columns" % (df.shape[0], df.shape[1]))
        print("Total NA Values : %d " % (total_na))
        print("%38s %10s     %10s %10s" % ("Column Name", "Data Type", "#Distinct", "NA Values"))
        col_name = df.columns
        dtyp = df.dtypes
        uniq = df.nunique()
        na_val = df.isna().sum()
        for i in range(len(df.columns)):
            print("%38s %10s   %10s %10s" % (col_name[i], dtyp[i], uniq[i], na_val[i]))
        
    else:
        print("Expect a DataFrame but got a %15s" % (type(df)))


initial_eda(df)
df.shape
# Out:
# Dimensions : 10000 rows, 12 columns
# Total NA Values : 7
#                            Column Name  Data Type      #Distinct  NA Values
#                        login_timestamp     object        10000          0
#                                user_id      int64         5729          0
#                             ip_address     object         6240          0
#                                country     object           54          0
#                                 region     object          176          4
#                                   city     object          807          3
#                                    asn      int64          409          0
#                      user_agent_string     object          378          0
#                                browser     object          117          0
#                              os_detail     object           51          0
#                            device_type     object            1          0
#                       is_login_success       bool            2          0
# (10000, 12)

# %%
categorical = [var for var in df.columns if df[var].dtype=='O']
print('There are {} categorical variables\n'.format(len(categorical)))
print('The categorical variables are :\n\n', categorical)
# Out:
# There are 9 categorical variables
#
# The categorical variables are :
#
#  ['login_timestamp', 'ip_address', 'country', 'region', 'city', 'user_agent_string', 'browser', 'os_detail', 'device_type']

# %% [markdown]
# ### Summary of categorical variables
# - There are 9 categorical variables in the dataset.
# -The categorical variables are given by `['login_timestamp', 'ip_address', 'country', 'region', 'city', 'user_agent_string', 'browser', 'os_detail', 'device_type']`
# - `is_login_success` is target

# %%
# find numerical variables
numerical = [var for var in df.columns if df[var].dtype!='O']
print('There are {} numerical variables\n'.format(len(numerical)))
print('The numerical variables are :\n\n', numerical)
# Out:
# There are 3 numerical variables
#
# The numerical variables are :
#
#  ['user_id', 'asn', 'is_login_success']

# %% [markdown]
# ### Summary of numerical variables
# - There are 6 numerical variables.
# - These are given by age, fnlwgt, education_num,capital_gain, capital_loss and hours_per_week.
# - All of the numerical variables are of discrete data type.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Explore Categorical Value

# %%
import ipaddress

# Preprocess the data
def preprocess_data(df):
    df_encoded = encode_ip_addresses(df['ip_address'])
    df_encoded.columns = ['ip_' + str(col) for col in df_encoded.columns]
    df = pd.concat([df.drop(columns='ip_address'), df_encoded], axis=1)
    df = preprocess_user_agent(df, 'user_agent_string', 'device_type')
    df = preprocess_timestamp(df, 'login_timestamp')
    # Perform additional preprocessing steps if necessary
    return df

# Encode IP addresses using one-hot encoding
def encode_ip_addresses(ip_addresses):
    encoded_ips = []
    max_prefixlen = 0

    # Find the maximum prefix length among the IP addresses
    for ip in ip_addresses:
        ip_obj = ipaddress.ip_address(ip)
        max_prefixlen = max(max_prefixlen, ip_obj.max_prefixlen)

    # Perform one-hot encoding for each IP address
    for ip in ip_addresses:
        ip_obj = ipaddress.ip_address(ip)
        ip_binary = bin(int(ip_obj))[2:].zfill(max_prefixlen)
        encoded_ip = [int(bit) for bit in ip_binary]
        encoded_ips.append(encoded_ip)

    encoded_df = pd.DataFrame(encoded_ips)
    return encoded_df

# Preprocess the user agent column
def preprocess_user_agent(df, user_agent_column, device_type):
    df['device_type'] = df[device_type]
    df['operating_system'] = df[user_agent_column].apply(lambda x: x.split('(')[1].split(';')[1])
    df.drop(columns=[user_agent_column], inplace=True)
    return df

# Preprocess the browser column
def preprocess_browser(df, browser_column):
    df['browser'] = df[browser_column].split(' ')[0]
    df.drop(columns=[browser_column], inplace=True)
    return df

# Preprocess the login_timestamp column
def preprocess_timestamp(df, timestamp_column):
    df[timestamp_column] = pd.to_datetime(df[timestamp_column])
    df['hour'] = df[timestamp_column].dt.hour
    df['day_of_week'] = df[timestamp_column].dt.dayofweek
    df['month'] = df[timestamp_column].dt.month
    df.drop(columns=[timestamp_column], inplace=True)
    return df

# %% [markdown]
# ## Split data into separate training and test set
# - split data into training and test
# - Declare feature vector and target variable ¶

# %%
from sklearn.model_selection import train_test_split

# X is the input variable
# Y is the output variable

X = df.drop(['is_login_success'], axis=1)
y = df['is_login_success']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 42)

# %%
# check the shape of X_train and X_test

X_train.shape, X_test.shape
# Out:
# ((6000, 11), (4000, 11))

# %% [markdown]
# ### Feature Engineering
#
# Feature Engineering is the process of transforming raw data into useful features that help us to understand our model better and increase its predictive power. I will carry out feature engineering on different types of variables.

# %%
X_train.dtypes
# Out:
# login_timestamp      object
# user_id               int64
# ip_address           object
# country              object
# region               object
# city                 object
# asn                   int64
# user_agent_string    object
# browser              object
# os_detail            object
# device_type          object
# dtype: object

# %%
X_train.head()
# Out:
#               login_timestamp              user_id      ip_address country  \
# 9761  2020-02-04 16:24:22.568  3366932303228343084   51.175.181.99      NO
# 3159  2020-02-03 18:45:02.737  4065021788984224296    81.166.6.161      NO
# 1489  2020-02-03 15:21:46.897 -4324475583306591935       10.0.4.23      RO
# 2987  2020-02-03 18:20:10.348 -7997252601171986227    2.148.17.151      NO
# 812   2020-02-03 14:02:01.915 -4324475583306591935  79.161.121.255      BR
#
#                region       city     asn  \
# 9761      Oslo County       Oslo   29695
# 3159        Innlandet    Elverum   29695
# 1489        Bucuresti  Bucharest  500039
# 2987  Møre og Romsdal    Ålesund    2119
# 812                 -          -   29695
#
#                                       user_agent_string  \
# 9761  Mozilla/5.0  (Macintosh; Intel Mac OS X 10_14_...
# 3159  Mozilla/5.0  (X11; CrOS aarch64 11316.123.0) A...
# 1489  Mozilla/5.0  (Macintosh; Intel Mac OS X 11_6_3...
# 2987  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6...
# 812   Mozilla/5.0  (X11; CrOS armv7l 5978.98.0) Appl...
#
#                      browser              os_detail device_type
# 9761        Chrome 90.0.4411       Mac OS X 10.14.6     desktop
# 3159  Chrome 69.0.3497.17.28  Chrome OS 11316.123.0     desktop
# 1489    Chrome 72.0.3626.115        Mac OS X 11.6.3     desktop
# 2987        Chrome 86.0.4202       Mac OS X 10.14.6     desktop
# 812      Chrome 72.0.3626.82    Chrome OS 5978.98.0     desktop

# %%
import category_encoders as ce


# One-hot encode the categorical features
# encode categorical variables with ordinal encoding
# see def preprocess_data(df) above
encoder = ce.OneHotEncoder(cols= ['login_timestamp', 'ip_address', 'country', 'region', 'city', 'user_agent_string', 'browser', 'os_detail', 'device_type']
)
X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)
X_train.head()
# Out:
#       login_timestamp_1  login_timestamp_2  login_timestamp_3  \
# 9761                  1                  0                  0
# 3159                  0                  1                  0
# 1489                  0                  0                  1
# 2987                  0                  0                  0
# 812                   0                  0                  0
#
#       login_timestamp_4  login_timestamp_5  login_timestamp_6  \
# 9761                  0                  0                  0
# 3159                  0                  0                  0
# 1489                  0                  0                  0
# 2987                  1                  0                  0
# 812                   0                  1                  0
#
#       login_timestamp_7  login_timestamp_8  login_timestamp_9  \
# 9761                  0                  0                  0
# 3159                  0                  0                  0
# 1489                  0                  0                  0
# 2987                  0                  0                  0
# 812                   0                  0                  0
#
#       login_timestamp_10  ...  os_detail_38  os_detail_39  os_detail_40  \
# 9761                   0  ...             0             0             0
# 3159                   0  ...             0             0             0
# 1489                   0  ...             0             0             0
# 2987                   0  ...             0             0             0
# 812                    0  ...             0             0             0
#
#       os_detail_41  os_detail_42  os_detail_43  os_detail_44  os_detail_45  \
# 9761             0             0             0             0             0
# 3159             0             0             0             0             0
# 1489             0             0             0             0             0
# 2987             0             0             0             0             0
# 812              0             0             0             0             0
#
#       os_detail_46  device_type_1
# 9761             0              1
# 3159             0              1
# 1489             0              1
# 2987             0              1
# 812              0              1
#
# [5 rows x 11551 columns]

# %%
X_train.shape
# Out:
# (6000, 11551)

# %% [markdown]
# ### Random Forest Classifier model with default parameters

# %%
# import Random Forest classifier
from sklearn.ensemble import RandomForestClassifier

# instantiate the classifier 
rfc = RandomForestClassifier(random_state=0)

# fit the model
rfc.fit(X_train, y_train)

# Predict the Test set results
y_pred = rfc.predict(X_test)


# Check accuracy score 
from sklearn.metrics import accuracy_score
print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.8640

# %% [markdown]
# Here, y_test are the true class labels and y_pred are the predicted class labels in the test-set.
#
# Here, I have build the Random Forest Classifier model with default parameter of n_estimators = 10. So, I have used 10 decision-trees to build the model. Now, I will increase the number of decision-trees and see its effect on accuracy.

# %% [markdown]
# ### Random Forest Classifier model with 100 Decision Trees

# %%
# instantiate the classifier with n_estimators = 100
rfc_100 = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model to the training set
rfc_100.fit(X_train, y_train)

# Predict on the test set results
y_pred_100 = rfc_100.predict(X_test)

# Check accuracy score 
print('Model accuracy score with 100 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred_100)))
# Out:
# Model accuracy score with 100 decision-trees : 0.8640

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# ### Gini importance

# %%
# create the classifier with n_estimators = default
clf = RandomForestClassifier(random_state=0)

# fit the model to the training set
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# view the feature scores

feature_scores = pd.Series(clf.feature_importances_, index=X_train.columns).sort_values(ascending=False)
feature_scores
# Out:
# user_id                 0.206316
# asn                     0.021142
# country_1               0.013081
# os_detail_3             0.004739
# country_3               0.004689
#                           ...
# login_timestamp_1854    0.000000
# login_timestamp_2511    0.000000
# login_timestamp_53      0.000000
# login_timestamp_5221    0.000000
# device_type_1           0.000000
# Length: 11551, dtype: float64

# %%
# Visualize feature scores of the features 
# Creating a seaborn bar plot

import matplotlib.pyplot as plt
import seaborn as sns

f, ax = plt.subplots(figsize=(30, 24))
ax = sns.barplot(x=feature_scores, y=feature_scores.index, data=df)
ax.set_title("Visualize feature scores of the features")
ax.set_yticklabels(feature_scores.index)
ax.set_xlabel("Feature importance score")
ax.set_ylabel("Features")
plt.show()

# %%
# Now i will drop feature_scores < 0.01
feature_scores_1 = feature_scores[feature_scores > 0.001]
feature_scores_1

f, ax = plt.subplots(figsize=(30, 24))
ax = sns.barplot(x=feature_scores_1, y=feature_scores_1.index, data=df)
ax.set_title("Visualize feature scores of the new features")
ax.set_yticklabels(feature_scores_1.index)
ax.set_xlabel("New Feature importance score")
ax.set_ylabel("New Features")
plt.show()

# %%
# list column name that feature_scores[feature_scores > 0.001]
drop_column = feature_scores[feature_scores <= 0.001].index
X_train = X_train.drop(drop_column, axis=1)
X_test = X_test.drop(drop_column, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_14859/1524756776.py in <module>
#       1 # list column name that feature_scores[feature_scores > 0.001]
#       2 drop_column = feature_scores[feature_scores <= 0.001].index
# ----> 3 X_train = X_train.drop(drop_column, axis=1)
#       4 X_test = X_test.drop(drop_column, axis=1)
#       5
#
# ~/.pyenv/versions/anaconda3-2022.10/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/anaconda3-2022.10/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~/.pyenv/versions/anaconda3-2022.10/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~/.pyenv/versions/anaconda3-2022.10/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~/.pyenv/versions/anaconda3-2022.10/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['region_2', 'ip_address_1084', 'city_37', 'city_21', 'country_9', 'ip_address_28', 'user_agent_string_18', 'region_22', 'city_48', 'city_108', 'country_6', 'user_agent_string_9', 'ip_address_678', 'ip_address_415', 'ip_address_851', 'user_agent_string_13', 'city_56', 'city_36', 'browser_20', 'user_agent_string_14', 'city_4', 'region_11', 'city_41', 'ip_address_1338', 'city_57', 'ip_address_1682', 'country_5', 'region_4', 'user_agent_string_19', 'city_97', 'ip_address_1779', 'ip_address_322', 'ip_address_39', 'city_29', 'browser_17', 'ip_address_2440', 'ip_address_1761', 'city_381', 'ip_address_791', 'browser_12', 'os_detail_8', 'ip_address_757', 'ip_address_1819', 'ip_address_1194', 'user_agent_string_24', 'city_32', 'city_65', 'ip_address_754', 'ip_address_2869', 'ip_address_104', 'ip_address_2573', 'ip_address_631', 'region_14', 'city_103', 'city_460', 'ip_address_5', 'city_17', 'user_agent_string_49', 'region_12', 'city_50', 'ip_address_1955', 'ip_address_2003', 'user_agent_string_23', 'city_16', 'region_15', 'browser_22', 'city_362', 'ip_address_2761', 'ip_address_980', 'ip_address_577', 'city_240', 'ip_address_202', 'city_131', 'ip_address_249', 'ip_address_66', 'region_26', 'ip_address_568', 'user_agent_string_74', 'browser_14', 'ip_address_235', 'ip_address_1544', 'user_agent_string_30', 'os_detail_13', 'ip_address_3076', 'os_detail_19', 'browser_30', 'ip_address_1032', 'city_9', 'ip_address_2398', 'user_agent_string_28', 'city_409', 'ip_address_1375', 'ip_address_698', 'browser_40', 'ip_address_123', 'city_85', 'ip_address_927', 'login_timestamp_1646', 'city_13', 'login_timestamp_3885', 'ip_address_665', 'user_agent_string_32', 'city_351', 'city_49', 'ip_address_1161', 'user_agent_string_10', 'login_timestamp_4839', 'ip_address_286', 'city_365', 'user_agent_string_34', 'login_timestamp_2705', 'login_timestamp_1803', 'ip_address_1232', 'user_agent_string_144', 'ip_address_889', 'login_timestamp_3818', 'ip_address_713', 'region_78', 'ip_address_1903', 'city_6', 'ip_address_1026', 'ip_address_957', 'login_timestamp_4475', 'ip_address_1066', 'ip_address_1332', 'ip_address_187', 'city_20', 'ip_address_1956', 'ip_address_138', 'ip_address_2364', 'city_219', 'login_timestamp_5231', 'login_timestamp_5180', 'login_timestamp_4948', 'ip_address_185', 'login_timestamp_3922', 'city_145', 'login_timestamp_3585', 'ip_address_2479', 'ip_address_734', 'city_76', 'login_timestamp_4959', 'ip_address_52', 'ip_address_944', 'login_timestamp_4163', 'user_agent_string_149', 'login_timestamp_5248', 'user_agent_string_62', 'login_timestamp_4844', 'user_agent_string_98', 'login_timestamp_4183', 'login_timestamp_4299', 'login_timestamp_3540', 'country_17', 'city_11', 'login_timestamp_5316', 'login_timestamp_596', 'ip_address_575', 'user_agent_string_159', 'ip_address_3', 'login_timestamp_4636', 'ip_address_1491', 'login_timestamp_2044', 'ip_address_2298', 'os_detail_18', 'ip_address_534', 'city_565', 'user_agent_string_97', 'ip_address_1388', 'ip_address_971', 'browser_18', 'ip_address_1113', 'user_agent_string_17', 'city_116', 'browser_19', 'city_15', 'login_timestamp_1023', 'login_timestamp_5811', 'ip_address_1977', 'ip_address_2346', 'login_timestamp_2585', 'login_timestamp_4579', 'city_82', 'ip_address_3006', 'user_agent_string_37', 'city_27', 'user_agent_string_81', 'city_14', 'ip_address_531', 'login_timestamp_1522', 'login_timestamp_5403', 'ip_address_561', 'ip_address_342', 'ip_address_293', 'login_timestamp_3442', 'login_timestamp_978', 'user_agent_string_36', 'city_73', 'login_timestamp_4810', 'login_timestamp_4385', 'login_timestamp_686', 'login_timestamp_2603', 'login_timestamp_4047', 'login_timestamp_2877', 'ip_address_1411', 'ip_address_1807', 'ip_address_3460', 'city_24', 'login_timestamp_5339', 'ip_address_3192', 'ip_address_2459', 'ip_address_1547', 'browser_31', 'user_agent_string_27', 'login_timestamp_5664', 'ip_address_129', 'login_timestamp_1344', 'login_timestamp_1077', 'city_195', 'ip_address_2004', 'login_time ...

# %%
X_train.shape
# Out:
# (6000, 56)

# %%
# Now, I will build the random forest model again and check accuracy.
clf = RandomForestClassifier(random_state=0)

# fit the model to the training set
clf.fit(X_train, y_train)

# Predict on the test set results
y_pred = clf.predict(X_test)

# Check accuracy score 
print('Model accuracy score with feature_scores < 0.01 variable removed : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with feature_scores < 0.01 variable removed : 0.8490

# %%
# how about use n_estimators = 100
clf = RandomForestClassifier(n_estimators=100, random_state=0)

# fit the model to the training set
clf.fit(X_train, y_train)

# Predict on the test set results
y_pred = clf.predict(X_test)

# Check accuracy score 
print('Model accuracy score with feature_scores < 0.01 variable removed : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with feature_scores < 0.01 variable removed : 0.8490

# %% [markdown]
# ## Evaluation
#
# A confusion matrix is a tool for summarizing the performance of a classification algorithm. A confusion matrix will give us a clear picture of classification model performance and the types of errors produced by the model. It gives us a summary of correct and incorrect predictions broken down by each category. The summary is represented in a tabular form.
#
# Four types of outcomes are possible while evaluating a classification model performance. These four outcomes are described below:-
#
# True Positives (TP) – True Positives occur when we predict an observation belongs to a certain class and the observation actually belongs to that class.
#
# True Negatives (TN) – True Negatives occur when we predict an observation does not belong to a certain class and the observation actually does not belong to that class.
#
# False Positives (FP) – False Positives occur when we predict an observation belongs to a certain class but the observation actually does not belong to that class. This type of error is called Type I error.
#
# False Negatives (FN) – False Negatives occur when we predict an observation does not belong to a certain class but the observation actually belongs to that class. This is a very serious error and it is called Type II error.
#
# These four outcomes are summarized in a confusion matrix given below.

# %% [markdown]
# ### Confusion Matrix

# %%
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[1081  362]
#  [ 242 2315]]

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Classification Report
#
# Classification report is another way to evaluate the classification model performance. It displays the precision, recall, f1 and support scores for the model. I have described these terms in later.

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.82      0.75      0.78      1443
#         True       0.86      0.91      0.88      2557
#
#     accuracy                           0.85      4000
#    macro avg       0.84      0.83      0.83      4000
# weighted avg       0.85      0.85      0.85      4000
